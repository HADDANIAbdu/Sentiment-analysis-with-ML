# %%
import matplotlib.pyplot as plt

# Sample data
x = [407 , 815 , 1223 , 1631 , 2199 , 2299]
y1 = [1.00 , 0.98 , 0.98 , 0.96 , 0.96 , 0.97]
y2 = [0.59 , 0.68 , 0.74 , 0.75 , 0.77 , 0.77]
y3 = [0.50 , 0.55 , 0.58 , 0.58 , 0.61 , 0.63]
y4 = [0.91 , 0.86 , 0.74 , 0.49 , 0.30 , 0.69]
y5 = [0.45 , 0.48 , 0.62 , 0.46 , 0.54 , 0.58]
y6 = [0.83 , 0.86 , 0.87 , 0.88 , 0.91 , 0.88]
y7 = [0.72 , 0.71 , 0.70 , 0.77 , 0.80 , 0.82]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12,6))

# Plot 1
ax.plot(x, y1, label='peur')

# Plot 2
ax.plot(x, y2, label='Tristesse')

# Plot 3
ax.plot(x, y3, label='Colere')

# Plot 1
ax.plot(x, y4, label='Joie')

# Plot 2
ax.plot(x, y5, label='Degout')

# Plot 3
ax.plot(x, y6, label='Surprise')

# Plot 3
ax.plot(x, y7, label='Decu')

# Set labels and title
ax.set_xlabel('Nombre des commentaires')
ax.set_ylabel('précision')
ax.set_title('Graphe de la précision de chaque sentiment par rapport au nombre\ndes commentaires en utilisant l\'algorithme de Classification K-Nearest Neighbors')

# Create the legend outside the plot
ax.legend(bbox_to_anchor=(1, 1))

# Save the plot to an image png
plt.savefig('common_graph.png', dpi=150)

# Show the plot
plt.show()
